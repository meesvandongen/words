# %% [markdown]
# # Search for "word" in Dutch Articles Dataset
#
# This notebook searches for the specific word in the Dutch news articles dataset and displays any matches with context.

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, let's import the necessary libraries for loading and searching through the dataset.

# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 2. Load the Dataset
#
# Load the Dutch articles dataset from the feather file and examine its structure.

# %%
# Load the dataset
dataset_path = Path("data/NOS_NL_articles_2015_mar_2025.feather")
print(f"Loading dataset from: {dataset_path}")

if dataset_path.exists():
    df = pd.read_feather(dataset_path)
    print(f"Dataset loaded successfully!")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    
    # Display basic info about the dataset
    print("\nDataset Info:")
    df.info()
    
    # Show first few rows
    print("\nFirst 3 rows:")
    display(df.head(3))
else:
    print(f"Error: Dataset file not found at {dataset_path}")
    print("Please check if the file exists in the correct location.")
# Out:
# Loading dataset from: data\NOS_NL_articles_2015_mar_2025.feather
# Dataset loaded successfully!
# Shape: (295259, 11)
# Columns: ['channel', 'url', 'type', 'title', 'keywords', 'section', 'description', 'published_time', 'modified_time', 'image', 'content']
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295259 entries, 1948 to 1932
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   channel         295259 non-null  object
#  1   url             295259 non-null  object
#  2   type            295259 non-null  object
#  3   title           295259 non-null  object
#  4   keywords        279786 non-null  object
#  5   section         289735 non-null  object
#  6   description     295259 non-null  object
#  7   published_time  295259 non-null  datetime64[ns]
#  8   modified_time   295259 non-null  object
#  9   image           295158 non-null  object
#  10  content         295259 non-null  object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 27.0+ MB
#
# First 3 rows:
#      channel                                                url     type  \
# 1948     nos  https://nos.nl/artikel/2011341-euro-nu-ook-in-...  article
# 1949     nos  https://nos.nl/artikel/2011343-start-2015-vol-...  article
# 1950     nos  https://nos.nl/artikel/2011346-letland-nieuwe-...  article
#
#                                                   title  \
# 1948                            Euro nu ook in Litouwen
# 1949  Start 2015 vol vreugde maar ook met gewonden e...
# 1950     Letland nieuwe voorzitter van de Europese Unie
#
#                                 keywords     section  \
# 1948                            eurozone    Economie
# 1949                        oud en nieuw  Binnenland
# 1950  EU-voorzitter, Italië, EU, Letland  Buitenland
#
#                                             description      published_time  \
# 1948  Vanaf vandaag betalen ze in Litouwen met de eu... 2015-01-01 00:32:52
# 1949  Nederland is met oliebollen en vuurwerk het ni... 2015-01-01 01:05:57
# 1950  Vanaf vandaag neemt Letland het stokje over va... 2015-01-01 02:32:34
#
#             modified_time                                              image  \
# 1948  2015-01-01 00:32:52  https://cdn.nos.nl/image/2015/01/01/48809/1200...
# 1949  2015-01-01 07:18:23  https://cdn.nos.nl/image/2015/01/01/48853/1200...
# 1950  2015-01-01 02:32:34  https://cdn.nos.nl/image/2015/01/01/48818/1200...
#
#                                                 content
# 1948  <h1>Euro nu ook in Litouwen</h1><p>In Litouwen...
# 1949  <h1>Start 2015 vol vreugde maar ook met gewond...
# 1950  <h1>Letland nieuwe voorzitter van de Europese ...

# %% [markdown]
# ## 3. Search for the Specific Word
#
# Now let's search for the word in the dataset across all text columns.

# %%
# Word to search for
search_word = "bloedneus"
print(f"Searching for the word: '{search_word}'")

# Initialize results
matches = []
total_count = 0

# Search through all text columns (assuming there are columns like 'title', 'text', 'content', etc.)
text_columns = [col for col in df.columns if df[col].dtype == 'object']
print(f"Searching in columns: {text_columns}")

for col in text_columns:
    # Convert to string and handle NaN values
    col_data = df[col].fillna('').astype(str)
    
    # Case-insensitive search
    mask = col_data.str.contains(search_word, case=False, na=False)
    
    if mask.any():
        matches_in_col = df[mask].copy()
        matches_in_col['found_in_column'] = col
        matches.append(matches_in_col)
        
        count_in_col = mask.sum()
        total_count += count_in_col
        print(f"Found {count_in_col} matches in column '{col}'")

print(f"\nTotal matches found: {total_count}")
# Out:
# Searching for the word: 'bloedneus'
# Searching in columns: ['channel', 'url', 'type', 'title', 'keywords', 'section', 'description', 'modified_time', 'image', 'content']
# Found 5 matches in column 'url'
# Found 5 matches in column 'title'
# Found 2 matches in column 'description'
# Found 65 matches in column 'content'
#
# Total matches found: 77

# %% [markdown]
# ## 4. Display Search Results
#
# Show the entries where the word was found, including context and relevant metadata.

# %%
if matches:
    # Combine all matches
    all_matches = pd.concat(matches, ignore_index=True)
    
    # Sort by published_time (year) - most recent first
    all_matches = all_matches.sort_values('published_time', ascending=False)
    
    print(f"Found {len(all_matches)} entries containing '{search_word}' (sorted by year, newest first):")
    print("=" * 60)
    
    for idx, (_, row) in enumerate(all_matches.iterrows()):
        print(f"\n--- Match {idx + 1} ---")
        print(f"Found in column: {row['found_in_column']}")
        print(f"Published: {row['published_time']}")
        print(f"Year: {row['published_time'].year}")
        
        # Display available metadata columns
        for col in df.columns:
            if col != row['found_in_column'] and col != 'published_time' and not pd.isna(row[col]) and str(row[col]).strip():
                print(f"{col}: {str(row[col])[:200]}{'...' if len(str(row[col])) > 200 else ''}")
        
        # Show the context around the word in the column where it was found
        text_content = str(row[row['found_in_column']])
        if search_word.lower() in text_content.lower():
            # Find the position of the word and show context
            word_pos = text_content.lower().find(search_word.lower())
            context_start = max(0, word_pos - 100)
            context_end = min(len(text_content), word_pos + len(search_word) + 100)
            context = text_content[context_start:context_end]
            
            print(f"\nContext in '{row['found_in_column']}':")
            print(f"...{context}...")
        
        print("\n" + "=" * 60)
else:
    print(f"No matches found for the word '{search_word}' in the dataset.")
# Out:
# Found 77 entries containing 'bloedneus' (sorted by year, newest first):
# ============================================================
#
# --- Match 1 ---
# Found in column: content
# Published: 2025-01-30 18:08:34
# Year: 2025
# channel: nos
# url: https://nos.nl/l/2553883
# type: liveblog
# title: Drie Nederlandse clubs naar tussenronde Europa League • AZ ontloopt met 4-3 Ajax als opponent
# keywords: FC Twente, Ajax, AZ, europa league
# description: In dit liveblog volgden we alles rondom de ontknoping van de competitiefase in de Europa League.
# modified_time: 2025-01-31 00:45:56
# image: https://cdn.nos.nl/image/2025/01/30/1185870/1024x576a.jpg
#
# Context in 'content':
# ...maar krijgt de bal hard op zijn neus en via de grond gaat de bal over. Van Wolfswinkel houdt er een bloedneus aan over.</p><p>FC Twente - Besiktas: 0-0</p><h2>AJA-GAL | 23' GOAL! Het is 1-0 voor Ajax</h2><p>GO...
#
# ============================================================
#
# --- Match 2 ---
# Found in column: content
# Published: 2024-11-20 18:19:49
# Year: 2024
# channel: nos
# url: https://nos.nl/l/2545266
# type: liveblog
# title: Dapper Twente kan Real Madrid net geen pijn doen in Champions League: 2-3
# keywords: Real Madrid, FC Twente, Champions League
# description: De voetbalsters van FC Twente verliezen hun vierde groepsduel in de Champions League nipt met 3-2 van Real Madrid.
# modified_time: 2024-11-20 23:38:50
# image: https://cdn.nos.nl/image/2024/11/20/1160017/1024x576a.jpg
#
# Context in 'content':
# ...orte tijd van Real Madrid wordt eerst spits Signe Bruun op haar neus geraakt en dat levert haar een bloedneus op.</p><p>De afgeslagen bal belandde vervolgens voor de voeten van verdedigster Rocío Gálvez en die...
#
# ============================================================
#
# --- Match 3 ---
# Found in column: content
# Published: 2024-06-11 18:06:51
# Year: 2024
# channel: nos
# url: https://nos.nl/artikel/2524111-fransman-overleden-bij-russische-lanceerbasis-in-kazachstan
# type: article
# title: Fransman overleden bij Russische lanceerbasis in Kazachstan
# keywords: Fransman, Bajkonoer
# section: Buitenland
# description: Volgens het Russische staatspersbureau RIA bezweek hij aan de hitte toen hij op weg was om de basis illegaal binnen te komen.
# modified_time: 2024-06-11 18:06:51
# image: https://cdn.nos.nl/image/2024/06/11/1093544/1024x576a.jpg
#
# Context in 'content':
# ...gens schaduw. Op het Russische Telegramkanaal 112 staat dat de 25-jarige reiziger herhaaldelijk een bloedneus kreeg en uiteindelijk bewusteloos neerviel.</p><p>Zijn metgezel zou zich naar de dichtstbijzijnde w...
#
# ============================================================
#
# --- Match 4 ---
# Found in column: content
# Published: 2024-04-20 11:34:48
# Year: 2024
# channel: nos
# url: https://nos.nl/artikel/2517468-geen-nieuwe-verdachten-in-beeld-van-mishandeling-conducteur
# type: article
# title: Geen nieuwe verdachten in beeld van mishandeling conducteur
# keywords: trein, mishandeling
# section: Binnenland
# description: Een jongen van 15, die kort na het incident werd opgepakt, is de enige verdachte. Vanwege het incident staan vanavond om 22.30 uur alle treinen drie minuten stil.
# modified_time: 2024-04-20 11:34:48
# image: https://cdn.nos.nl/image/2024/04/20/1074041/1024x576a.jpg
#
# Context in 'content':
# ...d. "Waar het om gaat is dat zij is belaagd door een groep jongeren en dat ze is mishandeld."</p><h2>Bloedneus</h2><p>Vakbond VVMC wil vooral benadrukken dat dit incident niet op zichzelf staat. "Dit soort ding...
#
# ============================================================
#
# --- Match 5 ---
# Found in column: content
# Published: 2023-06-28 14:18:11
# Year: 2023
# channel: nos
# url: https://nos.nl/artikel/2480630-boksers-kraus-en-beeloo-grijpen-op-europese-spelen-naast-olympisch-ticket
# type: article
# title: Boksers Kraus en Beeloo grijpen op Europese Spelen naast olympisch ticket
# keywords: Olympische Spelen, beeloo
# section: Boksen
# description: Het is boksers Gradus Kraus en Luna Beeloo tijdens de Europese Spelen niet gelukt om de halve finales te halen.
# modified_time: 2023-06-28 15:43:03
# image: https://cdn.nos.nl/image/2023/06/28/982181/1024x576a.jpg
#
# Context in 'content':
# ...kele rake klappen incasseren. In de derde ronde moest hij tot tweemaal toe behandeld worden aan een bloedneus. Hij kon vervolgens weinig meer uitrichten tegen Cavallaro.</p><p>Het kostte Kraus weinig energie o...
#
# ============================================================
#
# --- Match 6 ---
# Found in column: content
# Published: 2022-12-18 18:03:33
# Year: 2022
# channel: nos
# url: https://nos.nl/artikel/2456908-drie-agenten-mishandeld-door-jongeren-in-zoetermeer-drie-verdachten-vast
# type: article
# title: Drie agenten mishandeld door jongeren in Zoetermeer, drie verdachten vast
# section: Regionaal nieuws, Binnenland
# description: De agenten, en een betrokken portier, hebben aangifte gedaan van mishandeling. De drie verdachten zitten nog vast.
# modified_time: 2022-12-18 18:03:33
# image: https://cdn.nos.nl/image/2022/12/18/927141/1024x576a.jpg
#
# Context in 'content':
# ...een. Omstanders bij die arrestatie keerden zich tegen de politie en een van hen sloeg een agent een bloedneus.</p><h2>Zwaar onder invloed</h2><p>De agenten en de betrokken portier hebben aangifte gedaan van mi...
#
# ============================================================
#
# --- Match 7 ---
# Found in column: content
# Published: 2022-11-18 06:00:01
# Year: 2022
# channel: nos
# url: https://nos.nl/artikel/2452840-anderhalf-jaar-na-de-fatale-mishandeling-op-mallorca-doet-de-rechtbank-uitspraak
# type: article
# title: Anderhalf jaar na de fatale mishandeling op Mallorca doet de rechtbank uitspraak
# keywords: Carlo Heuvelman
# section: Binnenland
# description: In juli 2021 overlijdt Carlo Heuvelman (27) aan de gevolgen van een mishandeling. Negen verdachten staan terecht in de zaak.
# modified_time: 2022-11-18 06:00:01
# image: https://cdn.nos.nl/image/2022/11/18/916471/1024x576a.jpg
#
# Context in 'content':
# ... vechtpartij uit.</p><p>De slachtoffers doen later in Nederland aangifte van een gebroken duim, een bloedneus en een gebroken neus. Achteraf zegt justitie dat één van hen "hetzelfde lot" als Carlo had kunnen t...
#
# ============================================================
#
# --- Match 8 ---
# Found in column: content
# Published: 2022-11-16 18:07:02
# Year: 2022
# channel: nos
# url: https://nos.nl/artikel/2452676-nonnen-opgepakt-na-mishandeling-kinderen-in-italie
# type: article
# title: Nonnen opgepakt na mishandeling kinderen in Italië
# keywords: Italië
# section: Buitenland
# description: De publieke opinie op het eiland zou in tweeën verdeeld te zijn over het nieuws. Het centrum, dat veel samenwerkte met lokale vrijwilligersorganisaties, staat er namelijk ook hoog in aanzien.
# modified_time: 2022-11-16 18:07:02
# image: https://cdn.nos.nl/image/2022/11/16/916041/1024x576a.jpg
#
# Context in 'content':
# ...broer van het jongetje te hulp wil schieten, slaat de non ook hem in zijn gezicht, waardoor hij een bloedneus krijgt.</p><p>De video is gefilmd door een minderjarige die in het opvangcentrum verbleef, melden I...
#
# ============================================================
#
# --- Match 9 ---
# Found in column: content
# Published: 2022-10-02 11:44:11
# Year: 2022
# channel: nos
# url: https://nos.nl/liveblog/2446767-fc-volendam-nieuwe-hekkensluiter-az-nieuwe-koploper-na-ajax-en-psv-verspeelt-ook-feyenoord-punten
# type: liveblog
# title: FC Volendam nieuwe hekkensluiter, AZ nieuwe koploper • Na Ajax en PSV verspeelt ook Feyenoord punten
# keywords: eredivisie
# description: Het liveblog van de wedstrijden uit de achtste speelronde in de eredivisie. Feyenoord kan bij NEC niet profiteren van de misstappen van PSV en Ajax en FC Emmen doet de laatste plaats over aan Volendam...
# modified_time: 2022-10-02 22:20:07
# image: https://cdn.nos.nl/image/2022/10/02/902399/1024x576a.jpg
#
# Context in 'content':
# ...ord-rechtsback Marcus Pedersen ontbreekt op dat moment op die flank vanwege de behandeling voor een bloedneus.</p><p>NEC-Feyenoord 1-1</p><h2>EXC-UTR | 35' Dost verzuimt te scoren</h2><p>FC Utrecht bewijst zic...
#
# ============================================================
#
# --- Match 10 ---
# Found in column: content
# Published: 2022-03-21 13:55:02
# Year: 2022
# channel: nos
# url: https://nos.nl/artikel/2422133-zus-en-vriendin-dodelijk-slachtoffer-rosmalen-doen-aangifte-tegen-17-jarige-verdachte
# type: article
# title: Zus en vriendin dodelijk slachtoffer Rosmalen doen aangifte tegen 17-jarige verdachte
# keywords: steekincident, Jordy
# section: Binnenland
# description: De twee zeggen voorafgaand aan het dodelijke steekincident te zijn mishandeld door het meisje. De moeder van 22-jarige Jordy zegt volgens de advocaat dat ze de verdachte kennen en dat ze een kickbokse...
# modified_time: 2022-03-21 13:55:02
# image: https://cdn.nos.nl/image/2022/03/21/844329/1024x576a.jpg
#
# Context in 'content':
# .... De twee riepen vervolgens de hulp in van Jordy.</p><p>"Toen hij aankwam lag zijn vriendin met een bloedneus op de grond", aldus de advocaat. Wat er vervolgens precies gebeurde, is niet helemaal duidelijk maa...
#
# ============================================================
#
# --- Match 11 ---
# Found in column: content
# Published: 2022-03-19 11:41:32
# Year: 2022
# channel: nos
# url: https://nos.nl/artikel/2421829-de-tumultueuze-jaren-van-badr-hari-op-zoek-naar-eerste-overwinning-sinds-2015
# type: article
# title: De tumultueuze jaren van Badr Hari: op zoek naar eerste overwinning sinds 2015
# keywords: Arkadiusz Wrzosek
# section: Boksen
# description: Sinds 2016 staat Badr Hari onder contract bij de kickboksorganisatie Glory, maar hij wacht daar nog altijd op zijn eerste zege. Vanavond krijgt hij opnieuw een kans tegen de Pool Arkadiusz Wrzosek.
# modified_time: 2022-03-19 11:41:32
# image: https://cdn.nos.nl/image/2022/03/19/843471/1024x576a.jpg
#
# Context in 'content':
# ...n volgende hoge trap landde Hari verkeerd en moest hij opgeven met een enkelblessure.</p><h2>2020 - bloedneus en twee knock-downs</h2><p>Mede vanwege de coronapandemie kwam Hari pas eind 2020 weer in actie, di...
#
# ============================================================
#
# --- Match 12 ---
# Found in column: content
# Published: 2022-01-16 00:11:59
# Year: 2022
# channel: nos
# url: https://nos.nl/liveblog/2413194-keepersblunders-bepalen-eredivisieavond-boosheid-over-rentree-veelbesproken-vloet
# type: liveblog
# title: Keepersblunders bepalen eredivisieavond • Boosheid over rentree veelbesproken Vloet
# keywords: eredivisie
# description: Vitesse verslaat Feyenoord met 1-0 dankzij een blunder van doelman Justin Bijlow. Ook FC Twente en RKC Waalwijk winnen dankzij foutjes van de keepers. En de veelbesproken Rai Vloet maakt zijn rentree ...
# modified_time: 2022-01-16 00:12:06
# image: https://cdn.nos.nl/image/2022/01/15/821022/1024x576a.jpg
#
# Context in 'content':
# ...V vertrokken Joey Veerman, Anas Tahiri, start. Henk Veerman zit op de bank.   </p><h2>NEC-HER | 30' Bloedneus bij Kiomourtzoglou</h2><p>Orestis Kiomourtzoglou was al betrokken bij het kopduel, dat uiteindelijk...
#
# ============================================================
#
# --- Match 13 ---
# Found in column: content
# Published: 2021-09-08 01:23:54
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2396910-wervelend-oranje-dendert-over-turken-heen-6-1-van-gaal-euforisch-niet-normaal
# type: liveblog
# title: Wervelend Oranje dendert over Turken heen (6-1) • Van Gaal euforisch: 'Niet normaal'
# keywords: Oranje
# description: Het Nederlands elftal wervelt tegen Turkije in de Johan Cruijff Arena, wint met 6-1 en zet zo een grote stap richting deelname aan het WK van eind volgend jaar in Qatar.
# modified_time: 2021-09-08 01:24:41
# image: https://cdn.nos.nl/image/2021/09/07/782967/1024x576a.jpg
#
# Context in 'content':
# ... een al te fijne wedstrijd tegen zijn geboorteland. Zojuist moest hij even behandeld worden aan een bloedneus en hij gaat ook als eerste op de bon nadat hij aan de noodrem moest trekken tegen Georginio Wijnald...
#
# ============================================================
#
# --- Match 14 ---
# Found in column: content
# Published: 2021-08-04 19:01:55
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2392434-dit-was-dag-12-vetter-verbaast-zichzelf-kansloze-aftocht-handbalsters
# type: liveblog
# title: Dit was dag 12: Vetter verbaast zichzelf, kansloze aftocht handbalsters
# description: In dit liveblog volgen we dag 12 van de Olympische Spelen, met speciale aandacht voor Nederlandse prestaties.
# modified_time: 2021-08-04 19:02:37
# image: https://cdn.nos.nl/image/2021/08/04/771841/1024x576a.jpg
#
# Context in 'content':
# ... kans op een medaille meteen verkeken was. Vlak voordat Houtzager aan de beurt was, bleek Dante een bloedneus te hebben. Dat leidde tot enige vertraging en zorgen, waardoor de combinatie extra gespannen aan de...
#
# ============================================================
#
# --- Match 15 ---
# Found in column: content
# Published: 2021-06-18 19:58:26
# Year: 2021
# channel: nos
# url: https://nos.nl/collectie/13781/artikel/2385678-kroatie-blijft-ondanks-gelijkspel-tegen-tsjechie-zicht-houden-op-tweede-ronde
# type: article
# title: Kroatië blijft ondanks gelijkspel tegen Tsjechië zicht houden op tweede ronde
# keywords: EK voetbal, Kroatië
# section: Voetbal
# description: Op Hampden Park in Glasgow wordt het 1-1 tussen Kroatië en Tsjechië. De doelpunten komen op naam van Patrik Schick (Tsjechië) en Ivan Perisic (Kroatië).
# modified_time: 2021-06-18 22:54:19
# image: https://cdn.nos.nl/image/2021/06/18/754078/1024x576a.jpg
#
# Context in 'content':
# ...rsprong te komen. Verdediger Dejan Lovren plantte zijn elleboog op de neus van Schick, die daar een bloedneus aan overhield. Na bestudering van de beelden door de VAR kregen de Tsjechen een strafschop.</p><p>D...
#
# ============================================================
#
# --- Match 16 ---
# Found in column: content
# Published: 2021-06-17 00:28:52
# Year: 2021
# channel: nos
# url: https://nos.nl/collectie/13781/liveblog/2385262-italie-naar-achtste-finales-turken-op-rand-van-de-afgrond-russen-nog-in-de-race
# type: liveblog
# title: Italië naar achtste finales • Turken op rand van de afgrond • Russen nog in de race
# keywords: EK voetbal, Oranje, Nederlands elftal
# description: Het EK voetbal gaat vandaag verder met Finland-Rusland, Turkije-Wales en Italië-Zwitserland. Ook is er aandacht voor Oranje, dat donderdag de tweede groepswedstrijd speelt.
# modified_time: 2021-06-17 00:29:55
# image: https://cdn.nos.nl/image/2021/06/16/753323/1024x576a.jpg
#
# Context in 'content':
# ...d nog een doelpunt met zijn in een tulband gehulde hoofd. Ook nu moet hij even naar de kant met een bloedneus na een luchtduel met Söyünçü.</p><p>Moore gaat uiteraard wel gewoon verder, in tegenstelling tot Jo...
#
# ============================================================
#
# --- Match 17 ---
# Found in column: content
# Published: 2021-05-27 00:30:19
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2382446-villarreal-wint-europa-league-na-penaltythriller-psv-in-tweede-voorronde-cl
# type: liveblog
# title: Villarreal wint Europa League na penaltythriller • PSV in tweede voorronde CL
# description: De finale van de Europa League in het Poolse Gdansk ging tussen Villarreal en Manchester United. De Spanjaarden pakten hun allereerste prijs. Na verlengingen stond het 1-1, in de strafschoppenserie we...
# modified_time: 2021-05-27 00:30:42
# image: https://cdn.nos.nl/image/2021/05/27/746654/1024x576a.jpg
#
# Context in 'content':
# ...' Foyth terug met tulband</h2><p>Blijkbaar was er nog wat meer aan de hand met Foyth dan alleen een bloedneus. Hij is een tijdje verzorgd aan de zijlijn en is nu terug in het veld met een verband om zijn hoofd...
#
# ============================================================
#
# --- Match 18 ---
# Found in column: content
# Published: 2021-05-21 18:32:57
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2381699-nizzolo-sprint-eindelijk-naar-ritzege-in-giro-favorieten-sparen-voor-zoncolan
# type: liveblog
# title: Nizzolo sprint 'eindelijk' naar ritzege in Giro • Favorieten sparen voor Zoncolan
# keywords: Giro d'Italia
# description: De dertiende etappe van de Giro d'Italia gaat van Ravenna naar Verona en is zo vlak als een biljartlaken. Giacomo Nizzolo wint de rit, voor Edoardo Affini en Peter Sagan.
# modified_time: 2021-05-21 18:33:00
# image: https://cdn.nos.nl/image/2021/05/21/744916/1024x576a.jpg
#
# Context in 'content':
# ...https://t.co/4kstVmqRcQ</p><p>15:52</p><p>21 mei 2021</p></blockquote><h2>79 km - Gaviria heeft een bloedneus</h2><p>Fernando Gaviria heeft zich laten afzakken naar de ploegleiderswagen. Het lijkt erop dat de ...
#
# ============================================================
#
# --- Match 19 ---
# Found in column: content
# Published: 2021-03-21 23:11:53
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2373494-ajax-sluit-27ste-speelronde-af-met-simpele-zege-op-ado-den-haag-5-0
# type: liveblog
# title: Ajax sluit 27ste speelronde af met simpele zege op ADO Den Haag (5-0)
# keywords: Ajax, AZ
# description: Welkom in het liveblog! Vandaag komen de nummers een tot en met vier staan er vijf eredivisiewedstrijden op het programma. AZ ontvangt PSV. Vanavond komt Ajax in actie tegen ADO Den Haag.
# modified_time: 2021-03-21 23:12:30
# image: https://cdn.nos.nl/image/2021/03/21/726200/1024x576a.jpg
#
# Context in 'content':
# ... doellijn buitenspel staat, al lijkt hij de bal niet te raken.</p><p>AZ-PSV 1-0</p><h2>20' AZ-PSV - Bloedneus Dumfries</h2><p>International en PSV-aanvoerder Denzel Dumfries greep niet in bij de goal van Jespe...
#
# ============================================================
#
# --- Match 20 ---
# Found in column: content
# Published: 2021-02-27 11:19:01
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2370362-pec-heeft-weer-wat-lucht-na-zege-op-heerenveen-robben-terug-op-trainingsveld
# type: liveblog
# title: PEC heeft weer wat lucht na zege op Heerenveen • Robben terug op trainingsveld
# keywords: eredivisie
# description: Het is weer tijd om uitgebreid vooruit te blikken op het nationale en internationale voetbalweekend.
# modified_time: 2021-02-27 11:19:09
# image: https://cdn.nos.nl/image/2021/02/27/719132/1024x576a.jpg
#
# Context in 'content':
# ...Ton 💛💚</p><p>15:36</p><p>26 februari 2021</p></blockquote><h2>Koeman beëindigt persconferentie door bloedneus</h2><p>Trainer Ronald Koeman heeft zijn persconferentie voor het uitduel van Barcelona van zaterdag...
#
# ============================================================
#
# --- Match 21 ---
# Found in column: content
# Published: 2021-01-10 00:08:48
# Year: 2021
# channel: nos
# url: https://nos.nl/liveblog/2363665-2021-net-2020-vitesse-wint-az-weer-niet-en-utrecht-speelt-in-extremis-gelijk
# type: liveblog
# title: 2021 net 2020: Vitesse wint, AZ weer niet en Utrecht speelt in extremis gelijk
# keywords: eredivisie
# description: De laatste wedstrijd van 2020 was FC Utrecht-AZ (2-2) op 27 december. Vandaag beginnen we aan het tweede deel van de competitie, met onder meer Vitesse en AZ.
# modified_time: 2021-01-10 00:09:19
# image: https://cdn.nos.nl/image/2021/01/09/705713/1024x576a.jpg
#
# Context in 'content':
# ... bij. Dat heeft alles te maken met een blessurebehandeling van Vicente Besuijen, die met een flinke bloedneus kampte na een botsing met Vurnon Anita.</p><p>RKC Waalwijk - ADO Den Haag 0-1</p><h2>80' RKC blaft,...
#
# ============================================================
#
# --- Match 22 ---
# Found in column: content
# Published: 2021-01-09 18:34:43
# Year: 2021
# channel: nos
# url: https://nos.nl/artikel/2363697-met-nieuwe-routiniers-pakt-ado-drie-dure-punten-tegen-concurrent-rkc
# type: article
# title: Met nieuwe routiniers pakt ADO drie dure punten tegen concurrent RKC
# keywords: ADO Den Haag, RKC, eredivisie
# section: Voetbal
# description: ADO Den Haag wint in Waalwijk met 1-0 van RKC. Aanwinsten Marko Vejinovic en Daryl Janmaat beginnen in de basis.
# modified_time: 2021-01-09 18:34:43
# image: https://cdn.nos.nl/image/2021/01/09/705610/1024x576a.jpg
#
# Context in 'content':
# ...aar was counterend ondermaats.</p><p>In negen minuten die werden bijgeteld vanwege onder andere een bloedneus bij ADO-aanvaller Vicente Besuijen, wist RKC de kansen ook niet te verzilveren. In de 99ste minuut ...
#
# ============================================================
#
# --- Match 23 ---
# Found in column: title
# Published: 2020-12-19 23:20:02
# Year: 2020
# channel: nos
# url: https://nos.nl/artikel/2361331-badr-hari-verliest-met-bloedneus-en-twee-knock-downs-verrassend-van-adegbuyi
# type: article
# keywords: Benjamin Adegbuyi
# section: Boksen
# description: Op een geheime locatie in Rotterdam nam de kickbokser het op tegen de Roemeen Benjamin Adegbuyi.
# modified_time: 2020-12-19 23:20:02
# image: https://cdn.nos.nl/image/2020/12/19/700841/1024x576a.jpg
# content: <h1>Badr Hari verliest met bloedneus en twee knock-downs verrassend van Adegbuyi </h1><p>Badr Hari heeft bij zijn rentree in de ring niet kunnen winnen van de Roemeen Benny Adegbuyi. De partij verliep...
#
# Context in 'title':
# ...Badr Hari verliest met bloedneus en twee knock-downs verrassend van Adegbuyi  ...
#
# ============================================================
#
# --- Match 24 ---
# Found in column: url
# Published: 2020-12-19 23:20:02
# Year: 2020
# channel: nos
# type: article
# title: Badr Hari verliest met bloedneus en twee knock-downs verrassend van Adegbuyi
# keywords: Benjamin Adegbuyi
# section: Boksen
# description: Op een geheime locatie in Rotterdam nam de kickbokser het op tegen de Roemeen Benjamin Adegbuyi.
# modified_time: 2020-12-19 23:20:02
# image: https://cdn.nos.nl/image/2020/12/19/700841/1024x576a.jpg
# content: <h1>Badr Hari verliest met bloedneus en twee knock-downs verrassend van Adegbuyi </h1><p>Badr Hari heeft bij zijn rentree in de ring niet kunnen winnen van de Roemeen Benny Adegbuyi. De partij verliep...
#
# Context in 'url':
# ...https://nos.nl/artikel/2361331-badr-hari-verliest-met-bloedneus-en-twee-knock-downs-verrassend-van-adegbuyi...
#
# ============================================================
#
# --- Match 25 ---
# Found in column: content
# Published: 2020-12-19 23:20:02
# Year: 2020
# channel: nos
# url: https://nos.nl/artikel/2361331-badr-hari-verliest-met-bloedneus-en-twee-knock-downs-verrassend-van-adegbuyi
# type: article
# title: Badr Hari verliest met bloedneus en twee knock-downs verrassend van Adegbuyi
# keywords: Benjamin Adegbuyi
# section: Boksen
# description: Op een geheime locatie in Rotterdam nam de kickbokser het op tegen de Roemeen Benjamin Adegbuyi.
# modified_time: 2020-12-19 23:20:02
# image: https://cdn.nos.nl/image/2020/12/19/700841/1024x576a.jpg
#
# Context in 'content':
# ...<h1>Badr Hari verliest met bloedneus en twee knock-downs verrassend van Adegbuyi </h1><p>Badr Hari heeft bij zijn rentree in de ring nie...
#
# ============================================================
#
# --- Match 26 ---
# Found in column: content
# Published: 2020-03-06 22:11:39
# Year: 2020
# channel: nos
# url: https://nos.nl/artikel/2326112-pec-zwolle-in-slotfase-naast-fortuna-sittard-in-degradatiekraker
# type: article
# title: PEC Zwolle in slotfase naast Fortuna Sittard in degradatiekraker
# keywords: Fortuna Sittard, eredivisie, PEC Zwolle, voetbal
# section: Voetbal
# description: Fortuna leek na een treffer van George Cox op de overwinning af te stevenen, maar een benutte penalty van PEC in de slotfase gooit roet in het eten.
# modified_time: 2020-03-06 22:11:39
# image: https://cdn.nos.nl/image/2020/03/07/635154/1024x576a.jpg
#
# Context in 'content':
# ...el strijd en van een bedenkelijk niveau. PEC Zwolle had in de eerste helft de overhand, maar dat de bloedneus van Zwollenaar Thomas Lam één van de opmerkelijkste momenten was, was tekenend voor het duel.</p><p...
#
# ============================================================
#
# --- Match 27 ---
# Found in column: content
# Published: 2020-01-23 09:45:41
# Year: 2020
# channel: nos
# url: https://nos.nl/artikel/2319834-nadal-wint-en-kust-ballenmeisje-uitdagers-grote-drie-maken-geen-misstap
# type: article
# title: Nadal wint en kust ballenmeisje, uitdagers 'Grote Drie' maken geen misstap
# section: Tennis
# description: De Spanjaard is door naar de derde ronde van de Australian Open en moet en passant ook een ballenmeisje troosten.
# modified_time: 2020-01-23 13:43:37
# image: https://cdn.nos.nl/image/2020/01/23/623549/1024x576a.jpg
#
# Context in 'content':
# ...e ATP Finals, maar wellicht nog knapper was dat hij daar van zowel Federer als Djokovic won.</p><h2>Bloedneus deert Medvedev niet</h2><p>Daniil Medvedev, de Russische finalist van de US Open en nummer vier van...
#
# ============================================================
#
# --- Match 28 ---
# Found in column: content
# Published: 2019-09-29 12:21:54
# Year: 2019
# channel: nos
# url: https://nos.nl/artikel/2303848-twee-incidenten-met-geweld-tegen-agenten
# type: article
# title: Twee incidenten met geweld tegen agenten
# section: Binnenland
# description: In Castricum werd een agent meerdere keren in zijn gezicht geslagen en in Zoetermeer brak een agent zijn neus toen hij werd geslagen.
# modified_time: 2019-09-29 12:21:54
# image: https://cdn.nos.nl/image/2019/09/21/579081/1024x576a.jpg
#
# Context in 'content':
# ... tussen twee mannen te sussen. Een 17-jarige jongen sloeg hem in het gezicht. De agent werd met een bloedneus naar het ziekenhuis gebracht, waar bleek dat zijn neus gebroken is. De jongen is direct aangehouden...
#
# ============================================================
#
# --- Match 29 ---
# Found in column: content
# Published: 2019-02-07 18:15:33
# Year: 2019
# channel: nos
# url: https://nos.nl/artikel/2270947-voormalig-wielrenner-van-der-velde-ernstig-ziek
# type: article
# title: Voormalig wielrenner Van der Velde ernstig ziek
# keywords: van der velde
# section: Wielrennen
# description: De 62-jarige Johan van der Velde wordt momenteel behandeld in een ziekenhuis in Breda. Volgens BN De Stem lijdt hij aan acute leukemie.
# modified_time: 2019-02-07 18:15:33
# image: https://cdn.nos.nl/image/2019/02/07/529727/1200x675.jpg
#
# Context in 'content':
# ...ie lijdt.</p><p>Van der Velde kreeg vorige week in Spanje tijdens een trainingskamp van Roompot een bloedneus, die maar niet over wilde gaan. Na onderzoek kwam de ernstige ziekte aan het licht.</p><p>Hij won i...
#
# ============================================================
#
# --- Match 30 ---
# Found in column: content
# Published: 2018-09-23 00:08:40
# Year: 2018
# channel: nos
# url: https://nos.nl/artikel/2251650-joshua-slaat-povetkin-knock-out-en-verdedigt-wereldtitels-met-succes
# type: article
# title: Joshua slaat Povetkin knock-out en verdedigt wereldtitels met succes
# section: Boksen
# description: De 28-jarige Brit slaat zijn Russische opponent in de zevende ronde omver.
# modified_time: 2018-09-23 00:08:40
# image: https://cdn.nos.nl/image/2018/09/23/501772/1200x675.jpg
#
# Context in 'content':
# ... weerde zich echter kranig. Al in de eerste ronde bezorgde hij de Brit met een mooie combinatie een bloedneus en ook in de ronden erna deed hij volop mee.</p><p>Joshua had even tijd nodig, maar met een barrage...
#
# ============================================================
#
# --- Match 31 ---
# Found in column: content
# Published: 2018-09-22 23:18:29
# Year: 2018
# channel: nos
# url: https://nos.nl/liveblog/2251600-doelpuntrijke-avond-in-eredivisie-vvv-klimt-naar-vierde-plaats
# type: liveblog
# title: Doelpuntrijke avond in eredivisie; VVV klimt naar vierde plaats
# keywords: eredivisie, voetbal
# description: Fortuna Sittard-Willem II eindigt in 4-4, Excelsior-sc Heerenveen in 3-3, VVV-Venlo-NAC Breda wordt 3-0 en Vitesse speelt met 1-1 gelijk tegen ADO Den Haag.
# modified_time: 2018-09-22 23:18:34
# image: https://cdn.nos.nl/image/2018/09/22/501721/1200x675.jpg
#
# Context in 'content':
# ...>Doelpuntenmaker naar de kant</h2><p>Fortuna-doelpuntenmaker José Rodríguez houdt aan zijn goal een bloedneus over en wordt vervangen door oud-Willem II-speler Lars Hutten.</p><h2>22' GOAL VVV-VENLO</h2><p>Opo...
#
# ============================================================
#
# --- Match 32 ---
# Found in column: content
# Published: 2018-08-12 10:33:26
# Year: 2018
# channel: nos
# url: https://nos.nl/artikel/2245770-mazoeronak-grijpt-ek-goud-op-marathon-in-berlijn-deelstra-valt-uit
# type: article
# title: Mazoeronak grijpt EK-goud op marathon in Berlijn, Deelstra valt uit
# keywords: EK atletiek, Andrea Deelstra, Ruth van der Meijden
# section: Atletiek
# description: De 33-jarige Nederlandse startte met ambities aan de 42.195 meter op de EK in Berlijn.
# modified_time: 2018-08-12 11:40:09
# image: https://cdn.nos.nl/image/2018/08/12/493010/1200x675.jpg
#
# Context in 'content':
# ...e finish passen bij Mazoeronak, die kort na de start plots te maken kreeg met wat leek op een fikse bloedneus, en Calvin.</p><p>Mazoeronak sloeg in de laatste meters een gaatje, maar verkeek zich in de laatste...
#
# ============================================================
#
# --- Match 33 ---
# Found in column: content
# Published: 2018-06-24 15:18:23
# Year: 2018
# channel: nos
# url: https://nos.nl/artikel/2238143-nederlanders-krijgen-duitse-klappen-bij-kijken-duitsland-zweden
# type: article
# title: Nederlanders krijgen Duitse klappen bij kijken Duitsland-Zweden
# keywords: vechtpartij, matpartij, Duitsland
# section: Buitenland
# description: De Nederlanders keken in de plaats Nordhorn naar de WK-wedstrijd tussen Duitsland en Zweden.
# modified_time: 2018-06-24 15:18:52
# image: https://cdn.nos.nl/image/2017/07/04/400608/1200x675.jpg
#
# Context in 'content':
# ...et beveiligers. De beveiligers sloegen beide mannen in het gezicht. De man van 23 liep daardoor een bloedneus op en moest naar het ziekenhuis, de 26-jarige man verloor een aantal tanden.</p><p>Een Nederlander ...
#
# ============================================================
#
# --- Match 34 ---
# Found in column: content
# Published: 2018-06-23 23:26:33
# Year: 2018
# channel: nos
# url: https://nos.nl/liveblog/2237949-duitsland-leeft-nog-weer-winst-mexico-belgie-wervelt
# type: liveblog
# title: Duitsland leeft nog, weer winst Mexico, België wervelt
# keywords: voetbal
# description: Het was een uiterst boeiende WK-dag met Duitsland-Zweden (2-1), Zuid-Korea-Mexico (1-2) en België-Tunesië (5-2)
# modified_time: 2018-06-23 23:27:21
# image: https://cdn.nos.nl/image/2018/06/23/481771/1200x675.jpg
#
# Context in 'content':
# ...iet verder</h2><p>Sebastian Rudy kan niet verder en wordt vervangen voor Ilkay Gündogan.</p><h2>25' Bloedneus voor Rudy </h2><p>Sebastian Rudy wordt door opspringende Ola Toivonen in het gezicht geraakt en hee...
#
# ============================================================
#
# --- Match 35 ---
# Found in column: content
# Published: 2018-06-22 23:22:48
# Year: 2018
# channel: nos
# url: https://nos.nl/liveblog/2237784-kosovaarse-zwitsers-vellen-servie-brazilie-ontsnapt
# type: liveblog
# title: Kosovaarse Zwitsers vellen Servië; Brazilië ontsnapt
# keywords: WK 2018
# description: Twee Kosovaarse Zwitsers vellen Servië (2-1) en Nigeria en Brazilië winnen allebei met 2-0 van respectievelijk IJsland en Costa Rica.
# modified_time: 2018-06-22 23:23:03
# image: https://cdn.nos.nl/image/2018/06/22/481552/1200x675.jpg
#
# Context in 'content':
# ... gemor op de tribunes. Dit is nog geen hoogstaande wedstrijd.</p><h2>Casemiro even naar de kant met bloedneus</h2><h2>Blauw van de Brazilianen</h2><p>Brazilië speelt voor het eerst sinds 2010 weer eens in het ...
#
# ============================================================
#
# --- Match 36 ---
# Found in column: content
# Published: 2018-06-11 19:56:11
# Year: 2018
# channel: nos
# url: https://nos.nl/artikel/2236039-fontijn-via-oude-bekende-naar-finale-ek-boksen
# type: article
# title: Fontijn via oude bekende naar finale EK boksen
# keywords: Boksen
# section: Boksen
# description: De titelhoudster is in de halve finales veel te sterk voor de Duitse Sarah Scheurich. De jury was dan ook unaniem in haar oordeel: 5-0.
# modified_time: 2018-06-11 19:56:11
# image: https://cdn.nos.nl/image/2018/06/11/478714/1200x675.jpg
#
# Context in 'content':
# ...terk voor de Duitse Sarah Scheurich.</p><p>De jury was dan ook unaniem in haar oordeel: 5-0.</p><h2>Bloedneus</h2><p>Scheurich begon onstuimig, maar Fontijn bleef rustig en nam het initiatief over aan het eind...
#
# ============================================================
#
# --- Match 37 ---
# Found in column: content
# Published: 2018-04-14 23:04:42
# Year: 2018
# channel: nos
# url: https://nos.nl/liveblog/2227308-donkere-wolken-boven-twente-en-sparta-na-nederlagen
# type: liveblog
# title: Donkere wolken boven Twente en Sparta na nederlagen
# keywords: liveblog, eredivisie
# description: FC Twente verliest met 2-1 bij ADO Den Haag, Sparta ging met 7-0 over de knie bij Vitesse. Heerenveen wint met 2-0 bij VVV en PEC Zwolle speelt met 1-1 gelijk tegen Excelsior.
# modified_time: 2018-04-14 23:04:52
# image: https://cdn.nos.nl/image/2018/03/04/456655/1200x675.jpg
#
# Context in 'content':
# ...FC Twente heeft het nog altijd moeilijk tegen ADO in Den Haag. Assaidi is inmiddels - na zijn derde bloedneus - naar de kant gegaan en vervangen door Tighadouini. Bij ADO is de opvallend sterke Goppel vervange...
#
# ============================================================
#
# --- Match 38 ---
# Found in column: content
# Published: 2018-04-14 20:28:41
# Year: 2018
# channel: nos
# url: https://nos.nl/artikel/2227326-ado-spits-bjorn-johnsen-velt-onmachtig-fc-twente
# type: article
# title: ADO-spits Bjørn Johnsen velt onmachtig FC Twente
# keywords: ADO Den Haag, FC Twente, eredivisie
# section: Voetbal
# description: De hekkensluiter komt in Den Haag nog wel op voorsprong, maar moet buigen voor de dadendrang van de Noor die zijn 14de en 15de treffer maakt.
# modified_time: 2018-04-14 21:41:52
# image: https://cdn.nos.nl/image/2018/04/14/466124/1200x675.jpg
#
# Context in 'content':
# ...ente kwam amper meer in de buurt van het Haagse doel. Het had bovendien de pech dat Assaidi met een bloedneus gewisseld moest worden, terwijl Cristian Cuevas zijn twaalfde gele kaart van dit seizoen incasseerd...
#
# ============================================================
#
# --- Match 39 ---
# Found in column: content
# Published: 2018-03-17 23:14:07
# Year: 2018
# channel: nos
# url: https://nos.nl/liveblog/2222969-psv-laat-zich-niet-nog-een-keer-vernederen-twente-wint-weer-niet
# type: liveblog
# title: PSV laat zich niet nog een keer vernederen; Twente wint weer niet
# keywords: liveblog, voetbal
# description: In dit liveblog deden we verslag van de vier eredivisiewedstrijden van de zaterdag. De belangrijkste vraag was of PSV zich zou herstellen van de 5-0 bij Willem II.
# modified_time: 2018-03-17 23:14:13
# image: https://cdn.nos.nl/image/2018/03/04/456655/1200x675.jpg
#
# Context in 'content':
# ... we hadden moeten winnen</h2><h2>Stegeman: niet de boeiendste wedstrijd van het seizoen</h2><h2>57' Bloedneus</h2><p>Utrecht-verdediger Dumic houdt een bloedneus over aan een duel met Thorsby. Hij moet worden ...
#
# ============================================================
#
# --- Match 40 ---
# Found in column: content
# Published: 2018-02-03 22:58:33
# Year: 2018
# channel: nos
# url: https://nos.nl/liveblog/2215164-clubrecord-psv-verbeek-verliest-bij-heerenveen
# type: liveblog
# title: Clubrecord PSV; Verbeek verliest bij Heerenveen
# keywords: liveblog, eredivisie, voetbal
# description: PSV wint thuis voor de 21ste keer op rij en evenaart daarmee een clubrecord. Heerenveen verslaat FC Twente met 1-0 en Heracles-ADO wordt 1-1.
# modified_time: 2018-02-03 22:58:40
# image: https://cdn.nos.nl/image/2018/02/03/448595/1200x675.jpg
#
# Context in 'content':
# ...Gefeliciteerd Gastón! https://t.co/0lEgqa6K2c</p><p>19:48</p><p>3 februari 2018</p></blockquote><h2>Bloedneus</h2><p>Het bloed loopt uit de neus van Twente-middenvelder Maher na een harde aanraking met Bulthui...
#
# ============================================================
#
# --- Match 41 ---
# Found in column: content
# Published: 2017-07-20 15:26:15
# Year: 2017
# channel: nos
# url: https://nos.nl/artikel/2184174-vader-van-nederlandse-gevangene-in-china-alles-tussen-hemel-en-hel-is-mogelijk
# type: article
# title: Vader van Nederlandse gevangene in China: alles tussen hemel en hel is mogelijk
# keywords: rechtszaak, hoger beroep, Harm Fitié, China
# section: Buitenland
# description: Morgen dient in China het hoger beroep tegen Harm Fitié, een Nederlander die al 26 maanden in voorarrest zit.
# modified_time: 2017-07-20 19:32:44
# image: https://cdn.nos.nl/image/2017/07/20/404437/1200x675.jpg
#
# Context in 'content':
# .... Ook zijn er getuigenissen van de familie van het slachtoffer verdraaid en is nooit bewezen dat de bloedneus die het slachtoffer had door een klap van Harm is ontstaan. Er zijn geen dna-sporen op de vuist van...
#
# ============================================================
#
# --- Match 42 ---
# Found in column: content
# Published: 2017-05-30 14:56:30
# Year: 2017
# channel: nos
# url: https://nos.nl/artikel/2175778-schadevergoeding-voor-passagiers-mishandelde-transavia-piloot
# type: article
# title: Schadevergoeding voor passagiers mishandelde Transavia-piloot
# keywords: schadevergoeding
# section: Binnenland
# description: Na de mishandeling door twee passagiers in Barcelona besloot de aangeslagen bemanning met een leeg toestel terug te vliegen.Vanwege de vertraging die dat opleverde moet Transavia nu betalen.
# modified_time: 2017-05-30 16:37:02
# image: https://cdn.nos.nl/image/2017/05/30/388857/1200x675.jpg
#
# Context in 'content':
# ...n de politie uit te leveren. Daarop werd hij geschopt, gestompt en bespuugd. De piloot hield er een bloedneus en een snee in zijn neus aan over.</p><h2>Aangeslagen</h2><p>De bemanningsleden waren vervolgens zo...
#
# ============================================================
#
# --- Match 43 ---
# Found in column: content
# Published: 2017-05-20 22:56:15
# Year: 2017
# channel: nos
# url: https://nos.nl/liveblog/2174160-laatste-europese-ticket-voor-utrecht-of-az
# type: liveblog
# title: Laatste Europese ticket voor Utrecht of AZ
# keywords: liveblog, voetbal
# description: AZ verslaat FC Groningen evenals in Groningen met 4-1. Eerder plaatste ook FC Utrecht zich na een 2-1 zege op sc Heerenveen van de play-off-finale.
# modified_time: 2017-05-20 22:56:25
# image: https://cdn.nos.nl/image/2017/05/20/384611/1200x675.jpg
#
# Context in 'content':
# .... https://t.co/Bnf8tudc4a https://t.co/vpZiHoadJU</p><p>20:34</p><p>20 mei 2017</p></blockquote><h2>Bloedneus</h2><p>Ayoub staat met een bloedneus aan de kant. Het bloed spuit eruit bij de linkspoot. Hij komt ...
#
# ============================================================
#
# --- Match 44 ---
# Found in column: content
# Published: 2017-05-11 12:12:36
# Year: 2017
# channel: nos
# url: https://nos.nl/artikel/2172563-advies-aan-eu-hof-uber-moet-in-eu-taxi-regels-volgen
# type: article
# title: Advies aan EU-hof: Uber moet in EU taxi-regels volgen
# keywords: Europese Hof van Justitie, Uber
# section: Economie, Tech
# description: Het bedrijf is een gemengde dienst, zegt de advocaat-generaal, waarvan het transportonderdeel het belangrijkste is. Daardoor valt Uber onder de regels van de transportsector.
# modified_time: 2017-05-11 15:45:14
# image: https://cdn.nos.nl/image/2017/05/11/380372/1200x675.jpg
#
# Context in 'content':
# ...hierover te oordelen, maar het advies wordt wel vaak overgenomen. "De conclusies zijn voor Uber een bloedneus, maar nog geen knockout", concludeert The New York Times.</p><h2> Barcelona </h2><p>De zaak was aan...
#
# ============================================================
#
# --- Match 45 ---
# Found in column: content
# Published: 2017-01-09 07:11:45
# Year: 2017
# channel: nos
# url: https://nos.nl/artikel/2152119-bertens-dolt-met-coach-sluiter-tijdens-eerste-winstpartij
# type: article
# title: Bertens dolt met coach Sluiter tijdens eerste winstpartij
# keywords: Bertens, Kiki [tennisster], Cindy Burger, T
# section: Tennis
# description: Bij het WTA-toernooi van Hobart rekent ze - met een lach op haar gezicht - gedecideerd af met Annika Beck. Cindy Burger overleeft de eerste ronde niet.
# modified_time: 2017-01-09 12:21:14
# image: https://cdn.nos.nl/image/2017/01/09/345228/1200x675.jpg
#
# Context in 'content':
# ...oor Beck. Dat zag coach Raemon Sluiter al snel. Na de eerste vier games werd Beck behandeld aan een bloedneus. Die time-out werd door Sluiter benut om de baan op te komen en zijn pupil een vermakelijke peptalk...
#
# ============================================================
#
# --- Match 46 ---
# Found in column: content
# Published: 2016-12-28 12:26:14
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2150431-video-tesla-reageert-razendsnel-op-snelweg
# type: article
# title: Video: Tesla reageert razendsnel op snelweg
# keywords: Dashcam, ongeluk
# section: Regionaal nieuws
# description: Een dashcam legde alles vast. Dankzij de 'slimme auto' kon de man op tijd remmen.
# modified_time: 2016-12-28 13:24:23
# image: https://cdn.nos.nl/image/2016/12/28/342707/1200x675.jpg
#
# Context in 'content':
# ...lgens Van Hoesel ging het met de slachtoffers van het ongeluk verbazingwekkend goed. "Ze hadden een bloedneus en wat kleine schaafwondjes, maar geen ernstig letsel." </p><p>Hans Noordsij:</p><blockquote id="tw...
#
# ============================================================
#
# --- Match 47 ---
# Found in column: content
# Published: 2016-11-02 11:54:51
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2140982-rechter-vergeet-vonnis-verdachte-vertrekt-ongestraft
# type: article
# title: Rechter vergeet vonnis, verdachte vertrekt ongestraft
# keywords: rechtszaak, opmerkelijk, vonnis, rechter
# section: Opmerkelijk
# description: De rechter kende wel een schadevergoeding toe, maar vergat de straf officieel op te leggen.
# modified_time: 2016-11-02 11:54:51
# image: https://cdn.nos.nl/image/2016/11/02/329874/1200x675.jpg
#
# Context in 'content':
# ... uitgebreid op die beslissing in. Maar hij vergat de straf daarna ook officieel op te leggen.</p><p>Bloedneus </p><p>De zaak stamt uit 2013: een vrouw had een schadevergoeding geëist. Tijdens een avond stappen...
#
# ============================================================
#
# --- Match 48 ---
# Found in column: content
# Published: 2016-06-13 14:14:07
# Year: 2016
# channel: nos
# url: https://nos.nl/liveblog/2110846-pelle-beslist-het-duel-met-belgie-in-blessuretijd
# type: liveblog
# title: Pellè beslist het duel met België in blessuretijd
# keywords: Spanje, Zweden, België
# description: De Belgen beginnen het EK met een nederlaag tegen Italië. Eerder op de dag kwam Spanje tot winst en speelden Zweden en Ierland gelijk.
# modified_time: 2016-06-14 00:18:25
# image: https://cdn.nos.nl/image/2016/06/13/290100/1200x675.jpg
#
# Context in 'content':
# ...ë heeft afgetrapt voor de tweede helft. Kunnen de Rode Duivels iets aan de achterstand doen?</p><h2>Bloedneus</h2><h2>Adele</h2><p>Kirsten Sokol:</p><blockquote id="tweet"><p>@Kirsten_Sokol</p><p>Ongezien: @Ad...
#
# ============================================================
#
# --- Match 49 ---
# Found in column: content
# Published: 2016-05-21 17:19:51
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2106407-thiem-prolongeert-titel-in-nice
# type: article
# title: Thiem prolongeert titel in Nice
# keywords: Alexander Zverev, Thiem, Dominic [Oos][tennisser]
# section: Tennis
# description: De 22-jarige Oostenrijker verslaat de drie jaar jongere Alexander Zverev in de finale.
# modified_time: 2016-05-21 17:19:51
# image: https://cdn.nos.nl/image/2016/05/21/283950/1200x675.jpg
#
# Context in 'content':
# ... het eerste bedrijf met 2-4 voor, maar liet Thiem toch weer terugkomen. De Duitser kreeg op 5-4 een bloedneus en na een behandeling leverde hij de set met een dubbele fout in.</p><p>Op zijn beurt kon Thiem in ...
#
# ============================================================
#
# --- Match 50 ---
# Found in column: content
# Published: 2016-05-13 18:10:38
# Year: 2016
# channel: nos
# url: https://nos.nl/liveblog/2104854-eredivisionisten-beginnen-goed-aan-play-offs
# type: liveblog
# title: Eredivisionisten beginnen goed aan play-offs
# keywords: Almere City FC [voetbalclub], MVV [voetbalclub]
# description: De Graafschap en Willem II verslaan respectievelijk MVV en Almere City met 1-0. Ook FC Eindhoven en Go Ahead Eagles winnen.
# modified_time: 2016-05-13 23:01:48
# image: https://cdn.nos.nl/image/2016/05/13/281825/1200x675.jpg
#
# Context in 'content':
# ...ts. Met het hoofd maakt de 'Ajax-beul' zo'n tien minuten voor tijd de 0-1 op bezoek bij MVV.</p><h2>Bloedneus</h2><p>Een bloedneus voor VVV-speler Moreno Rutten, maar hij kan doorspelen.</p><h2>Lachwekkend?</h...
#
# ============================================================
#
# --- Match 51 ---
# Found in column: title
# Published: 2016-02-26 08:52:47
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2089110-inzet-iraanse-verkiezingen-hardliners-een-bloedneus-slaan
# type: article
# keywords: Iran, verkiezingen
# section: Buitenland
# description: Voor het eerst sinds de sancties tegen Iran zijn opgeheven zijn er verkiezingen in het land. Centraal staat de strijd tussen hervormers en conservatieven.
# modified_time: 2016-02-26 08:52:47
# image: https://cdn.nos.nl/image/2016/02/26/259709/1200x675.jpg
# content: <h1>'Inzet Iraanse verkiezingen: hardliners een bloedneus slaan'</h1><p>Iran gaat vandaag naar de stembus en dat is voor het eerst sinds Westerse landen de sancties tegen het land grotendeels hebben o...
#
# Context in 'title':
# ...'Inzet Iraanse verkiezingen: hardliners een bloedneus slaan'...
#
# ============================================================
#
# --- Match 52 ---
# Found in column: content
# Published: 2016-02-26 08:52:47
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2089110-inzet-iraanse-verkiezingen-hardliners-een-bloedneus-slaan
# type: article
# title: 'Inzet Iraanse verkiezingen: hardliners een bloedneus slaan'
# keywords: Iran, verkiezingen
# section: Buitenland
# description: Voor het eerst sinds de sancties tegen Iran zijn opgeheven zijn er verkiezingen in het land. Centraal staat de strijd tussen hervormers en conservatieven.
# modified_time: 2016-02-26 08:52:47
# image: https://cdn.nos.nl/image/2016/02/26/259709/1200x675.jpg
#
# Context in 'content':
# ...<h1>'Inzet Iraanse verkiezingen: hardliners een bloedneus slaan'</h1><p>Iran gaat vandaag naar de stembus en dat is voor het eerst sinds Westerse landen de s...
#
# ============================================================
#
# --- Match 53 ---
# Found in column: url
# Published: 2016-02-26 08:52:47
# Year: 2016
# channel: nos
# type: article
# title: 'Inzet Iraanse verkiezingen: hardliners een bloedneus slaan'
# keywords: Iran, verkiezingen
# section: Buitenland
# description: Voor het eerst sinds de sancties tegen Iran zijn opgeheven zijn er verkiezingen in het land. Centraal staat de strijd tussen hervormers en conservatieven.
# modified_time: 2016-02-26 08:52:47
# image: https://cdn.nos.nl/image/2016/02/26/259709/1200x675.jpg
# content: <h1>'Inzet Iraanse verkiezingen: hardliners een bloedneus slaan'</h1><p>Iran gaat vandaag naar de stembus en dat is voor het eerst sinds Westerse landen de sancties tegen het land grotendeels hebben o...
#
# Context in 'url':
# ...https://nos.nl/artikel/2089110-inzet-iraanse-verkiezingen-hardliners-een-bloedneus-slaan...
#
# ============================================================
#
# --- Match 54 ---
# Found in column: content
# Published: 2016-02-15 01:03:17
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2087022-kobe-s-laatste-kunstje-als-all-star
# type: article
# title: Kobe's laatste kunstje als All-Star
# keywords: Bryant, Kobe [VSt][basketballer], Jordan, Michael [VS][basketballer], All Stars [NBA All Stars team][Basketbal], Basketbal
# section: Basketbal
# description: De NBA staat het hele weekend in het teken van show. En van het afscheid van Kobe Bryant, de man die al twee decennia bij de All-Stars hoort.
# modified_time: 2016-02-15 01:03:17
# image: https://cdn.nos.nl/image/2016/02/15/256851/1200x675.jpg
#
# Context in 'content':
# ...door een klein dieptepunt. Een klap in het gezicht van Dwyane Wade zorgde voor de eerste (en enige) bloedneus in zijn carrière als All-Star.</p><h3>2012 NBA All-Star: Kobe`s Bloody Nose</h3><h2>Eerbetoon</h2><...
#
# ============================================================
#
# --- Match 55 ---
# Found in column: content
# Published: 2016-01-29 12:32:12
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2083595-leerling-15-mishandeld-door-familie-schoolgenoot
# type: article
# title: Leerling (15) mishandeld door familie schoolgenoot
# keywords: vechtpartij, Bonhoeffer College
# section: Binnenland
# description: Het meisje had een bloedneus en een tand door haar lip. De politie heeft twee vrouwen aangehouden.
# modified_time: 2016-01-29 12:32:12
# image: https://cdn.nos.nl/image/2016/01/29/252256/1200x675.jpg
#
# Context in 'content':
# ...
# section: Tennis
# description: De als derde geplaatste Brit Andy Murray laat in de eerste ronde van de Australian Open geen spaan heel van het Duitse toptalent.
# modified_time: 2016-01-19 05:10:51
# image: https://cdn.nos.nl/image/2016/01/19/249338/1200x675.jpg
#
# Context in 'content':
# ...<h1>Zes games, een kapot racket en een bloedneus voor Zverev</h1><p>Andy Murray heeft zich geplaatst voor de tweede ronde van de Australian Open. De...
#
# ============================================================
#
# --- Match 59 ---
# Found in column: url
# Published: 2016-01-19 05:10:51
# Year: 2016
# channel: nos
# type: article
# title: Zes games, een kapot racket en een bloedneus voor Zverev
# keywords: Murray, Andy [GBr][tennisser], Open Australische [tennis toernooi], Zverev Alexander
# section: Tennis
# description: De als derde geplaatste Brit Andy Murray laat in de eerste ronde van de Australian Open geen spaan heel van het Duitse toptalent.
# modified_time: 2016-01-19 05:10:51
# image: https://cdn.nos.nl/image/2016/01/19/249338/1200x675.jpg
# content: <h1>Zes games, een kapot racket en een bloedneus voor Zverev</h1><p>Andy Murray heeft zich geplaatst voor de tweede ronde van de Australian Open. De viervoudig verliezend finalist liet met 6-1, 6-2, 6...
#
# Context in 'url':
# ...https://nos.nl/artikel/2081310-zes-games-een-kapot-racket-en-een-bloedneus-voor-zverev...
#
# ============================================================
#
# --- Match 60 ---
# Found in column: title
# Published: 2016-01-19 05:10:51
# Year: 2016
# channel: nos
# url: https://nos.nl/artikel/2081310-zes-games-een-kapot-racket-en-een-bloedneus-voor-zverev
# type: article
# keywords: Murray, Andy [GBr][tennisser], Open Australische [tennis toernooi], Zverev Alexander
# section: Tennis
# description: De als derde geplaatste Brit Andy Murray laat in de eerste ronde van de Australian Open geen spaan heel van het Duitse toptalent.
# modified_time: 2016-01-19 05:10:51
# image: https://cdn.nos.nl/image/2016/01/19/249338/1200x675.jpg
# content: <h1>Zes games, een kapot racket en een bloedneus voor Zverev</h1><p>Andy Murray heeft zich geplaatst voor de tweede ronde van de Australian Open. De viervoudig verliezend finalist liet met 6-1, 6-2, 6...
#
# Context in 'title':
# ...Zes games, een kapot racket en een bloedneus voor Zverev...
#
# ============================================================
#
# --- Match 61 ---
# Found in column: content
# Published: 2016-01-16 17:45:21
# Year: 2016
# channel: nos
# url: https://nos.nl/liveblog/2080880-de-graafschap-pec-en-vitesse-goed-uit-startblokken
# type: liveblog
# title: De Graafschap, PEC en Vitesse goed uit startblokken
# keywords: eredivisie
# description: Ook AZ won zaterdag zijn eerste wedstrijd na de winterstop. Vrijdag boekte Twente al een ruime zege op Heracles: 4-0.
# modified_time: 2016-01-16 23:12:10
# image: https://cdn.nos.nl/image/2016/01/16/248688/1200x675.jpg
#
# Context in 'content':
# .... Stand: 3-1. Nog zo'n twintig minuten.</p><h2>Wissel PEC</h2><p>Marinus erin, Dekker eruit.</p><h2>Bloedneus</h2><p>PEC Zwolle:</p><blockquote id="tweet"><p>@PECZwolle</p><p>66' PEC Zwolle ook even met tien m...
#
# ============================================================
#
# --- Match 62 ---
# Found in column: content
# Published: 2015-12-13 11:08:07
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2074877-niet-supporter-maar-ploeggenoot-bezorgde-foor-bloedneus
# type: article
# title: Niet supporter, maar ploeggenoot bezorgde Foor bloedneus
# keywords: Navarone Foor, cambuur, NEC, eredivisie, voetbal
# section: Voetbal
# description: Na de verloren wedstrijd verliet de geëmotioneerde middenvelder van NEC met bebloed gezicht het veld.
# modified_time: 2015-12-13 11:08:07
# image: https://cdn.nos.nl/image/2015/12/12/240340/1200x675.jpg
#
# Context in 'content':
# ...<h1>Niet supporter, maar ploeggenoot bezorgde Foor bloedneus</h1><p>De bloedneus die NEC-speler Navarone Foor opliep na de verloren wedstrijd tegen Cambuur is n...
#
# ============================================================
#
# --- Match 63 ---
# Found in column: title
# Published: 2015-12-13 11:08:07
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2074877-niet-supporter-maar-ploeggenoot-bezorgde-foor-bloedneus
# type: article
# keywords: Navarone Foor, cambuur, NEC, eredivisie, voetbal
# section: Voetbal
# description: Na de verloren wedstrijd verliet de geëmotioneerde middenvelder van NEC met bebloed gezicht het veld.
# modified_time: 2015-12-13 11:08:07
# image: https://cdn.nos.nl/image/2015/12/12/240340/1200x675.jpg
# content: <h1>Niet supporter, maar ploeggenoot bezorgde Foor bloedneus</h1><p>De bloedneus die NEC-speler Navarone Foor opliep na de verloren wedstrijd tegen Cambuur is niet veroorzaakt door een projectiel uit ...
#
# Context in 'title':
# ...Niet supporter, maar ploeggenoot bezorgde Foor bloedneus...
#
# ============================================================
#
# --- Match 64 ---
# Found in column: url
# Published: 2015-12-13 11:08:07
# Year: 2015
# channel: nos
# type: article
# title: Niet supporter, maar ploeggenoot bezorgde Foor bloedneus
# keywords: Navarone Foor, cambuur, NEC, eredivisie, voetbal
# section: Voetbal
# description: Na de verloren wedstrijd verliet de geëmotioneerde middenvelder van NEC met bebloed gezicht het veld.
# modified_time: 2015-12-13 11:08:07
# image: https://cdn.nos.nl/image/2015/12/12/240340/1200x675.jpg
# content: <h1>Niet supporter, maar ploeggenoot bezorgde Foor bloedneus</h1><p>De bloedneus die NEC-speler Navarone Foor opliep na de verloren wedstrijd tegen Cambuur is niet veroorzaakt door een projectiel uit ...
#
# Context in 'url':
# ...https://nos.nl/artikel/2074877-niet-supporter-maar-ploeggenoot-bezorgde-foor-bloedneus...
#
# ============================================================
#
# --- Match 65 ---
# Found in column: title
# Published: 2015-12-02 22:18:30
# Year: 2015
# channel: nos
# url: https://nos.nl/op3/artikel/2072697-kim-kardashian-heeft-een-bloedneus-en-dat-mag-niet
# type: article
# keywords: Hollywoodsterren, huiselijk geweld, reclamecampagne
# section: Buitenland
# description: Een kunstenaar gebruikte foto's van vrouwelijke beroemdheden in een campagne tegen huiselijk geweld. Zonder toestemming. Daar zijn ze niet blij mee.
# modified_time: 2015-12-02 22:18:30
# image: https://cdn.nos.nl/image/2015/12/02/237618/1200x675.jpg
# content: <h1>Kim Kardashian heeft een bloedneus en dat mag niet</h1><p>Madonna, Miley Cyrus en Emma Watson, met blauwe plekken en bloedneuzen op de foto. De Amerikaanse photoshop-kunstenaar Alexsandro Palombo ...
#
# Context in 'title':
# ...Kim Kardashian heeft een bloedneus en dat mag niet...
#
# ============================================================
#
# --- Match 66 ---
# Found in column: url
# Published: 2015-12-02 22:18:30
# Year: 2015
# channel: nos
# type: article
# title: Kim Kardashian heeft een bloedneus en dat mag niet
# keywords: Hollywoodsterren, huiselijk geweld, reclamecampagne
# section: Buitenland
# description: Een kunstenaar gebruikte foto's van vrouwelijke beroemdheden in een campagne tegen huiselijk geweld. Zonder toestemming. Daar zijn ze niet blij mee.
# modified_time: 2015-12-02 22:18:30
# image: https://cdn.nos.nl/image/2015/12/02/237618/1200x675.jpg
# content: <h1>Kim Kardashian heeft een bloedneus en dat mag niet</h1><p>Madonna, Miley Cyrus en Emma Watson, met blauwe plekken en bloedneuzen op de foto. De Amerikaanse photoshop-kunstenaar Alexsandro Palombo ...
#
# Context in 'url':
# ...https://nos.nl/op3/artikel/2072697-kim-kardashian-heeft-een-bloedneus-en-dat-mag-niet...
#
# ============================================================
#
# --- Match 67 ---
# Found in column: content
# Published: 2015-12-02 22:18:30
# Year: 2015
# channel: nos
# url: https://nos.nl/op3/artikel/2072697-kim-kardashian-heeft-een-bloedneus-en-dat-mag-niet
# type: article
# title: Kim Kardashian heeft een bloedneus en dat mag niet
# keywords: Hollywoodsterren, huiselijk geweld, reclamecampagne
# section: Buitenland
# description: Een kunstenaar gebruikte foto's van vrouwelijke beroemdheden in een campagne tegen huiselijk geweld. Zonder toestemming. Daar zijn ze niet blij mee.
# modified_time: 2015-12-02 22:18:30
# image: https://cdn.nos.nl/image/2015/12/02/237618/1200x675.jpg
#
# Context in 'content':
# ...<h1>Kim Kardashian heeft een bloedneus en dat mag niet</h1><p>Madonna, Miley Cyrus en Emma Watson, met blauwe plekken en bloedneuzen op de...
#
# ============================================================
#
# --- Match 68 ---
# Found in column: content
# Published: 2015-08-27 11:44:09
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2054292-man-mishandeld-na-aanspreken-kind-op-gedrag
# type: article
# title: Man mishandeld na aanspreken kind op gedrag
# section: Binnenland
# description: Het kind had een sierbal uit een tuin in Breda meegenomen.
# modified_time: 2015-08-27 11:44:09
# image: https://cdn.nos.nl/image/2015/08/27/187120/1200x675.jpg
#
# Context in 'content':
# ...ond de vader voor de deur, nu met een tweede man. De bewoner werd weer geslagen en geschopt.</p><h2>Bloedneus</h2><p>Politieagenten vonden het slachtoffer gewond in huis, met een bloedneus, zwellingen in het g...
#
# ============================================================
#
# --- Match 69 ---
# Found in column: content
# Published: 2015-08-13 15:43:00
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2051804-man-in-ijmuiden-herkend-als-de-rennende-rukker
# type: article
# title: Man in IJmuiden herkend als 'de rennende rukker'
# keywords: rennende rukker, schennispleger
# section: Binnenland
# description: De schennispleger, die de laatste weken actief is in de havenstad, is in een supermarkt herkend door een van zijn slachtoffers.
# modified_time: 2015-08-13 15:43:00
# image: https://cdn.nos.nl/image/2015/07/25/178695/1200x675.jpg
#
# Context in 'content':
# ...van de man beten van zich af. Zo sloeg een meisje van 17 hem in zijn gezicht. Hij liep daardoor een bloedneus op. Een ander slachtoffer spoot de man nat met een tuinslang.</p><h2>Tegengehouden</h2><p>Een van d...
#
# ============================================================
#
# --- Match 70 ---
# Found in column: content
# Published: 2015-08-13 07:05:00
# Year: 2015
# channel: nos
# url: https://nos.nl/op3/liveblog/2051717-nosop3
# type: liveblog
# title: NOSop3
# keywords: nieuws
# description: De NOS op 3-stroom van donderdag 13 augustus 2015.
# modified_time: 2015-08-13 22:20:32
# image: https://cdn.nos.nl/image/2015/08/13/183561/1200x675.jpg
#
# Context in 'content':
# ...erd herkend door een meisje van 17. Ze was vorige week zo geschrokken door z'n actie dat ze hem een bloedneus sloeg.</p><p>NH Nieuws:</p><blockquote id="tweet"><p>@NHNieuws</p><p>"Ik ben in de Lidl naar hem to...
#
# ============================================================
#
# --- Match 71 ---
# Found in column: content
# Published: 2015-08-07 07:10:11
# Year: 2015
# channel: nos
# url: https://nos.nl/op3/liveblog/2050811-stroom
# type: liveblog
# title: Stroom
# keywords: nieuws
# description: De NOS op 3-stroom van vrijdag 7 augustus 2015.
# modified_time: 2015-08-07 22:08:23
# image: https://cdn.nos.nl/image/2015/08/07/182089/1200x675.jpg
#
# Context in 'content':
# ...e gemeente.</p><h2>Vrouw spuit 'rennende rukker' nat</h2><p>Eerder kreeg de rennende rukker nog een bloedneus geslagen, nu hebben zijn acties hem een nat pak opgeleverd. "Ik hoorde rare geluiden en dacht: wat ...
#
# ============================================================
#
# --- Match 72 ---
# Found in column: description
# Published: 2015-04-13 12:26:04
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2029996-go-ahead-onderzoekt-vechtpartij-wijnaldum-met-fans
# type: article
# title: Go Ahead onderzoekt vechtpartij Wijnaldum met fans
# keywords: Go Ahead Eagles [voetbalclub], Giliano Wijnaldum
# section: Voetbal
# modified_time: 2015-04-13 12:26:04
# image: https://cdn.nos.nl/image/2015/04/13/148784/1200x675.jpg
# content: <h1>Go Ahead onderzoekt vechtpartij Wijnaldum met fans</h1><p>Go Ahead Eagles is een onderzoek begonnen naar een incident na de thuisnederlaag tegen FC Twente (1-3). Volgens De Telegraaf gaat het om e...
#
# Context in 'description':
# ...De linksback zou racistisch zijn bejegend en een supporter een bloedneus hebben geslagen. De club bevestigt het incident, maar meer niet....
#
# ============================================================
#
# --- Match 73 ---
# Found in column: content
# Published: 2015-04-13 12:26:04
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2029996-go-ahead-onderzoekt-vechtpartij-wijnaldum-met-fans
# type: article
# title: Go Ahead onderzoekt vechtpartij Wijnaldum met fans
# keywords: Go Ahead Eagles [voetbalclub], Giliano Wijnaldum
# section: Voetbal
# description: De linksback zou racistisch zijn bejegend en een supporter een bloedneus hebben geslagen. De club bevestigt het incident, maar meer niet.
# modified_time: 2015-04-13 12:26:04
# image: https://cdn.nos.nl/image/2015/04/13/148784/1200x675.jpg
#
# Context in 'content':
# ... te weinig inzet toonde. Vervolgens ontstond er een vechtpartij en daarbij liep één van de fans een bloedneus op.</p><p>Stewards van de club schoten Wijnaldum te hulp. Daarop riepen de supporters nog wat, waar...
#
# ============================================================
#
# --- Match 74 ---
# Found in column: content
# Published: 2015-03-25 14:27:52
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2026815-hiddink-oefent-met-dost-en-huntelaar
# type: article
# title: Hiddink oefent met Dost en Huntelaar
# keywords: voetbal, Oranje, Nederlands elftal
# section: Voetbal
# description: Een vooralsnog blessurevrij Nederlands elftal werkt in alle rust toe naar de EK-kwalificatiewedstrijd tegen Turkije.
# modified_time: 2015-03-25 14:27:52
# image: https://cdn.nos.nl/image/2015/03/25/144007/14.jpg
#
# Context in 'content':
# ...r. Later werden Dost en Afellay afgelost door respectievelijk Luuk de Jong en Memphis Depay.</p><h2>Bloedneus Bruma</h2><p>De aanvallende internationals namen het op tegen Gregory van der Wiel, Jeffrey Bruma, ...
#
# ============================================================
#
# --- Match 75 ---
# Found in column: content
# Published: 2015-03-09 09:34:07
# Year: 2015
# channel: nos
# url: https://nos.nl/artikel/2023639-toeteractie-ns-oorverdovend-op-stations
# type: article
# title: Toeteractie NS oorverdovend op stations
# keywords: toeteractie, Typhoonactie
# section: Binnenland
# description: Veel mensen in Nederland hebben de toeteractie gehoord. NS-personeel protesteerde daarmee tegen toenemend geweld in treinen.
# modified_time: 2015-03-09 09:34:07
# image: https://cdn.nos.nl/image/2015/03/09/139143/14.jpg
#
# Context in 'content':
# ...egen NS-personeel in de trein. Zo werd op station Utrecht Centraal vanmorgen nog een conducteur een bloedneus geslagen.</p><p>NOS-verslaggever Jeroen de Jager was op Utrecht Centraal waar hij luisterde naar ee...
#
# ============================================================
#
# --- Match 76 ---
# Found in column: content
# Published: 2015-03-09 07:27:00
# Year: 2015
# channel: nos
# url: https://nos.nl/op3/liveblog/2023627-nos-op-3-kort
# type: liveblog
# title: NOS op 3 Kort
# keywords: nieuws, Laatste nieuws, Updates
# description: Een overzicht van het laatste nieuws, geselecteerd door de redactie van NOS op 3.
# modified_time: 2015-03-09 22:53:58
# image: https://cdn.nos.nl/image/2015/03/03/137364/1200x675.jpg
#
# Context in 'content':
# ...et filmpje: een lichamelijke beperking is geen excuus om niet voor IS te vechten.</p><h2>Conducteur bloedneus geslagen op Utrecht CS</h2><p>Een NS-conducteur is vanmorgen in zijn gezicht geslagen op Utrecht Ce...
#
# ============================================================
#
# --- Match 77 ---
# Found in column: content
# Published: 2015-02-13 06:48:38
# Year: 2015
# channel: nos
# url: https://nos.nl/op3/liveblog/2018988-updates-13-2
# type: liveblog
# title: Updates 13-2
# keywords: Kort
# description: De stroom
# modified_time: 2015-02-13 22:25:55
# image: https://cdn.nos.nl/image/2015/02/13/132231/1200x675.jpg
#
# Context in 'content':
# ...edase weg in Tilburg. Twee auto’s raakten zwaar beschadigd. De whatsappende bestuurder hield er een bloedneus aan over. De rest kwam met de schrik vrij. Er ontstond wel een flinke file.</p><h2>Thaise golfer sl...
#
# ============================================================

# %%
# Yearly summary of matches
if matches:
    all_matches = pd.concat(matches, ignore_index=True)
    
    # Extract year from published_time and create summary
    all_matches['year'] = all_matches['published_time'].dt.year
    yearly_summary = all_matches.groupby(['year', 'found_in_column']).size().reset_index(name='count')
    yearly_total = all_matches.groupby('year').size().reset_index(name='total_matches')
    
    print(f"\n{'='*50}")
    print("YEARLY SUMMARY OF MATCHES")
    print(f"{'='*50}")
    
    for year in sorted(yearly_total['year'].unique(), reverse=True):
        year_total = yearly_total[yearly_total['year'] == year]['total_matches'].iloc[0]
        print(f"\n{year}: {year_total} total matches")
        
        # Show breakdown by column for this year
        year_data = yearly_summary[yearly_summary['year'] == year]
        for _, row in year_data.iterrows():
            print(f"  - {row['found_in_column']}: {row['count']} matches")
    
    # Create and display summary DataFrame
    print(f"\n{'='*30}")
    print("Summary Table:")
    display(yearly_total.sort_values('year', ascending=False))
# Out:
# ==================================================
# YEARLY SUMMARY OF MATCHES
# ==================================================
#
# 2025: 1 total matches
#   - content: 1 matches
#
# 2024: 3 total matches
#   - content: 3 matches
#
# 2023: 1 total matches
#   - content: 1 matches
#
# 2022: 7 total matches
#   - content: 7 matches
#
# 2021: 10 total matches
#   - content: 10 matches
#
# 2020: 5 total matches
#   - content: 3 matches
#   - title: 1 matches
#   - url: 1 matches
#
# 2019: 2 total matches
#   - content: 2 matches
#
# 2018: 11 total matches
#   - content: 11 matches
#
# 2017: 5 total matches
#   - content: 5 matches
#
# 2016: 16 total matches
#   - content: 11 matches
#   - description: 1 matches
#   - title: 2 matches
#   - url: 2 matches
#
# 2015: 16 total matches
#   - content: 11 matches
#   - description: 1 matches
#   - title: 2 matches
#   - url: 2 matches
#
# ==============================
# Summary Table:
#     year  total_matches
# 10  2025              1
# 9   2024              3
# 8   2023              1
# 7   2022              7
# 6   2021             10
# 5   2020              5
# 4   2019              2
# 3   2018             11
# 2   2017              5
# 1   2016             16
# 0   2015             16

# %% [markdown]
# ## 5. Count Word Occurrences
#
# Calculate the total number of times the word appears in the dataset with breakdown by columns.

# %%
# Detailed occurrence count
print(f"Detailed word occurrence analysis for '{search_word}':")
print("=" * 50)

occurrence_summary = {}
total_word_count = 0

for col in text_columns:
    col_data = df[col].fillna('').astype(str)
    
    # Count total occurrences (not just rows containing the word)
    word_count_in_col = 0
    for text in col_data:
        word_count_in_col += len(re.findall(re.escape(search_word), text, re.IGNORECASE))
    
    if word_count_in_col > 0:
        occurrence_summary[col] = word_count_in_col
        total_word_count += word_count_in_col
        print(f"Column '{col}': {word_count_in_col} occurrences")

print(f"\nTotal word occurrences across all columns: {total_word_count}")
print(f"Total unique articles/rows containing the word: {total_count}")

# Create a summary DataFrame
if occurrence_summary:
    summary_df = pd.DataFrame([
        {'Column': col, 'Occurrences': count, 'Percentage': (count/total_word_count)*100}
        for col, count in occurrence_summary.items()
    ])
    
    print("\nSummary table:")
    display(summary_df)
else:
    print(f"\nThe word '{search_word}' was not found in any text columns of the dataset.")
# Out:
# Detailed word occurrence analysis for 'bloedneus':
# ==================================================
# Column 'url': 5 occurrences
# Column 'title': 5 occurrences
# Column 'description': 2 occurrences
# Column 'content': 89 occurrences
#
# Total word occurrences across all columns: 101
# Total unique articles/rows containing the word: 77
#
# Summary table:
#         Column  Occurrences  Percentage
# 0          url            5    4.950495
# 1        title            5    4.950495
# 2  description            2    1.980198
# 3      content           89   88.118812
